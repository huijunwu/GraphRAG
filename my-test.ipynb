# %% [markdown]
# # conda
#
# https://github.com/JayLZhou/GraphRAG?tab=readme-ov-file#dependencies
# ```
# conda env create -f experiment.yml
# ```
#
#
# To activate this environment, use
#
#     $ conda activate digimon
#
# To deactivate an active environment, use
#
#     $ conda deactivate

# %% [markdown]
# # llm (not used)
#
#
#
# install ollama ubuntu24.04 https://ollama.com/download
# ```
# curl -fsSL https://ollama.com/install.sh | sh
# ```
#
# run a model https://ollama.com/library/qwen3
# ```
# ollama run qwen3:30b-a3b --nowordwrap
# ollama run nomic-embed-text:latest
# ```
#
# test embedding
# ```
# curl http://localhost:11434/api/embeddings -d '{
#   "model": "nomic-embed-text",
#   "prompt": "The sky is blue because of Rayleigh scattering"
# }'
#
# curl http://localhost:11434/api/embed -d '{
#   "model": "nomic-embed-text:latest",
#   "input": "Why is the sky blue?"
# }'
# ```
#
# stop all running models
# ```
# ollama ps | awk 'NR>1 {print $1}' | xargs -n1 ollama stop
# ```
